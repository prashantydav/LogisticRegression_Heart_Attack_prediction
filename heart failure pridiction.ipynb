# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('heart.csv')

# %%
data.shape
# Out:
# (918, 12)

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# ## Data Analysis

# %%
sns.set_theme()
fig = plt.figure(figsize = (15,6))
sns.lineplot(x = data.Age , y = data.Cholesterol)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Cholesterol'>

# %% [markdown]
# ##### Cholesterol level of females are more than males

# %%
sns.barplot(x = data['Sex'] , y = data['Cholesterol'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Cholesterol'>

# %%
fig = plt.figure(figsize = (15,6))
sns.lineplot(x = data['Age'] , y = data['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='HeartDisease'>

# %%
# fig = plt.figure(figsize = (15,6))
sns.barplot(x = data['Sex'] , y = data['HeartDisease'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='HeartDisease'>

# %% [markdown]
# #### males seems to have heart disease more than females

# %%
sns.barplot(  x = data.HeartDisease ,y = data.Cholesterol ,)
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
data.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
cor = data.corr(method = 'pearson')
mask = np.triu(cor)
sns.heatmap(cor,mask = mask , linewidth = 5 , annot = True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
new_data = pd.get_dummies(data)
new_data.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  ChestPainType_TA  \
# 0      0      1                  0  ...                  0                 0
# 1      1      0                  0  ...                  1                 0
# 2      0      1                  0  ...                  0                 0
# 3      1      0                  1  ...                  0                 0
# 4      0      1                  0  ...                  1                 0
#
# ...

# %%
X = new_data.drop('HeartDisease' , axis = 1)
Y = new_data['HeartDisease']
x_train,  x_test , y_train, y_test = train_test_split(X, Y , test_size = 0.2)

# %%
logreg = LogisticRegression(n_jobs = -1)
logreg.fit(x_train , y_train)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
logreg.score(x_train , y_train)
# Out:
# 0.8623978201634878

# %%
print('Accuracy: ' , logreg.score(x_test , y_test))
# Out:
# Accuracy:  0.8695652173913043

# %%
test_predict = logreg.predict(x_test)
print(test_predict[:10])
print(y_test[:10].to_list())
# Out:
# [1 0 1 0 1 1 1 1 1 1]
# [1, 0, 1, 1, 1, 1, 0, 0, 1, 0]

# %%
plt.figure(figsize =(6,6))
sns.histplot(y_test , color = 'green' , kde = True)
sns.histplot(test_predict , color = 'red' ,kde = True)
plt.title("real value vs predicted value")
plt.show()
